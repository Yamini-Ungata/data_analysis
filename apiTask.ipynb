# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'500',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'f77f3bfc-b3be-4a0e-88be-919c9c6bb9ff',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:00:43.572Z', 'error_code': 0, 'error_message': None, 'elapsed': 28, 'credit_count': 3, 'notice': None, 'total_count': 8818}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10821, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
df=pd.json_normalize(data['data'])

# %%
df
# Out:
#         id              name  symbol                  slug  num_market_pairs  \
# 0        1           Bitcoin     BTC               bitcoin             10821
# 1     1027          Ethereum     ETH              ethereum              8428
# 2      825       Tether USDt    USDT                tether             74897
# 3     1839               BNB     BNB                   bnb              2070
# 4     5426            Solana     SOL                solana               626
# ..     ...               ...     ...                   ...               ...
# 495   9176  RocketX exchange     RVF  rocket-vault-rocketx                64
# 496  19055   Solidus Ai Tech  AITECH       solidus-ai-tech                45
# 497   3884        Function X      FX            function-x                30
# 498   3661  Stronghold Token     SHX      stronghold-token                30
# 499   3437         ABBC Coin    ABBC             abbc-coin                89
#
#                    date_added  \
# ...

# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'f77f3bfc-b3be-4a0e-88be-919c9c6bb9ff',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:06:39.450Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 1648, 'name': 'yfrfpcnjr5q', 'symbol': 'us7twzhjz1', 'slug': 'ms6olj3jtc', 'cmc_rank': 8548, 'num_market_pairs': 5387, 'circulating_supply': 879, 'total_supply': 702, 'max_supply': 1334, 'infinite_supply': None, 'last_updated': '2024-02-20T06:06:39.450Z', 'date_added': '2024-02-20T06:06:39.450Z', 'tags': ['9xw0ffdo7sl', '9xif0etm79c', 'zmlht1bjin', 'ukkl7pptj6a', 'cyrssd8757c', '9d9xyn4kjl9', 'r6mto6y5r88', 'afiso37xo9g', 'lsz3161hcsr', 'hhufzyb431'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.23178337337078436, 'volume_24h': 4020, 'volume_change_24h': 0.8829285799144362, 'percent_change_1h': 0.6310022051488973, 'percent_change_24h': 0.00841024595463824, 'percent_change_7d': 0.5786671897179292, 'market_cap': 0.030896135569725702, 'market_cap_dominan
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
df=pd.json_normalize(data['data'])

# %%
df
# Out:
#      id         name       symbol          slug  cmc_rank  num_market_pairs  \
# 0  1648  yfrfpcnjr5q   us7twzhjz1    ms6olj3jtc      8548              5387
# 1  8187   rnpliknym2   y3k7jighz9  09rewtpnoml7      1963              6757
# 2   708  fe2nl6xnn7i  dzq4xlgfhcd   e009ent0qhj      2129              5668
# 3  7109  3bw1rbrlecf  fdbdk2wmq97   q0jdbdf949e      7606              7598
# 4  6296  yak9cjvktmi   m21n8ndlqu   0kagcc2mggw      9575              4087
# 5  4745   hw84cdzr99  5mv7rte2zh7    hvtf48cj1z      7768              2994
# 6  4349  t38ihlony5h  l0yw4gtlftq   jkvm3psyizp      5629              5275
# 7  1000   d6zsa5j4fm  h2vnu1qqdd5  0hervozyv4b9      7146              9012
# 8  7568   r0k9fnzyif  68951899913   xlg2hfjavgs      1069              5526
# 9  9647  60zq3vkje63   vja0ik4ill    ljby6uebwd      2178              2714
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# ...

# %%
import requests
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/16.jpg","link":"https:\/\/randomfox.ca\/?i=16"}

# %%
fox=page.json()
image=fox['image']
print(image)
# Out:
# https://randomfox.ca/images/34.jpg

# %%
#using actual api

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'http://api.weatherapi.com/v1/current.xml?key=<3801ce2c629c455e9a270306242002>&q=London'  #actual url
parameters = {
  'start':'1',
  'limit':'2767',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '3801ce2c629c455e9a270306242002',  #actual api key
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-95-1e900a03f228> in <cell line: 21>()
#      21 try:
#      22   response = session.get(url, params=parameters)
# ---> 23   data = json.loads(response.text)
#      24   print(data)
#      25 except (ConnectionError, Timeout, TooManyRedirects) as e:
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
df=pd.json_normalize(data['list'])

# %%
df
# Out:
#             dt                                            weather  visibility  \
# 0   1708419600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 1   1708430400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 2   1708441200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 3   1708452000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 4   1708462800  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 5   1708473600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 6   1708484400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 7   1708495200  [{'id': 804, 'main': 'Clouds', 'description': ...        2310
# 8   1708506000  [{'id': 600, 'main': 'Snow', 'description': 'l...         499
# 9   1708516800  [{'id': 600, 'main': 'Snow', 'description': 'l...         876
# 10  1708527600  [{'id': 600, 'main': 'Snow', 'description': 'l...         451
# ...
